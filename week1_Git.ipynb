# %% [markdown]
# # Load the code

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd /content/drive/MyDrive/tobigs
# Out:
# /content/drive/MyDrive/tobigs

# %%
# !git clone https://sbY99:<ACCESS_TOKEN>@github.com/ymnseol/Tobigs_20_Git_assignment.git
# Out:
# Cloning into 'Tobigs_20_Git_assignment'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 49 (delta 8), reused 4 (delta 4), pack-reused 39
# Receiving objects: 100% (49/49), 11.49 KiB | 250.00 KiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !ls
# Out:
# Data				     week1_2_DCGAN_Example.ipynb  week1_git
# Tobigs_20_Git_assignment	     week1_EDA.ipynb
# week1_1_Random_Forest_Example.ipynb  week1_Framework.ipynb

# %%
cd Tobigs_20_Git_assignment/group3
# Out:
# /content/drive/MyDrive/tobigs/Tobigs_20_Git_assignment/group3

# %%
# !ls
# Out:
# main.py  player1  player2  player3  player4  player5  README.md

# %% [markdown]
# # Excute the main.py

# %%
# !python3 main.py
# Out:
# < Tobigs 20 정규세션 git >
# 투빅스 20기 여러분들 환영합니다.
# 여기는 정규세션 과제 월드입니다.
# 그리고 저는 당신의 과제 달성을 도와줄 과제 요정입니다 ^^
# 과제 중 막히는 부분이 있으면 '19기 이영아'에게 언제든지 카톡 주세요~
# 지시에 따라 여러분들에 대해 알려주시면 됩니다!
#
#
#
# 안녕하세요! 설유민님!
# 아직 모두의 프로필이 작성되지 않았어요.
# 각 player폴더 안에 'profile.json' 을 작성하고 다시 와 주세요.
# 파일을 작성한 뒤에는 팀장의 레포지토리에 'git commit'하는 것 잊지 마세요!
# 이 파일을 실행하는 사람은 'git pull' 을 통해 모두의 파일을 다시 내려받아야 합니다!
#
# 빠이빠이!
# __main__.MissonNotFinishError: profile.json 파일을 모두 작성 후 다시 찾아와주세요!

# %% [markdown]
# # Edit group3/player3/profile.json
#  - Edit the json file manually

# %% [markdown]
# # git push

# %%
# !git config --global user.email "didtmdqlsdl@gmail.com"
# !git config --global user.name "sbY99"

# %%
# !git remote -v

# %%
# !git add .
# !git commit -m '프로필 수정'
# Out:
# [main 8f29a42] 프로필 수정
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !git branch -v
# Out:
# * main 8f29a42 [ahead 1] 프로필 수정

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 487 bytes | 81.00 KiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/ymnseol/Tobigs_20_Git_assignment.git
#    c09a6ec..8f29a42  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
